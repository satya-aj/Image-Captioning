# %% [markdown]
# # Image Captioning with Attention

# %% [markdown]
# ### download dependecies

# %%
# !pip install -q tqdm
# !pip install -q tensorflow-gpu==2.0.0-beta0

# %%
### Libraries
## You'll generate plots of attention in order to see which parts of an image
## our model focuses on during captioning
from __future__ import absolute_import, division, print_function, unicode_literals
import matplotlib.pyplot as plt

## Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tqdm import tqdm
from glob import glob
from PIL import Image
import re
import numpy as np
import os
import time
import json
import pickle
import tensorflow as tf

# %% [markdown]
# ## Download and prepare the MS-COCO Dataset

# %%
annotation_zip  = tf.keras.utils.get_file('captions.zip', cache_subdir=os.path.abspath('.'), 
                                          origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip', extract = True)
annotation_file = os.path.dirname(annotation_zip) + '/annotations/captions_train2014.json'

name_of_zip = 'train2014.zip'
if not os.path.exists(os.path.abspath('.') + '/' + name_of_zip):
    image_zip = tf.keras.utils.get_file(name_of_zip, cache_subdir=os.path.abspath('.'), 
                                        origin = 'http://images.cocodataset.org/zips/train2014.zip', extract = True)
    PATH = os.path.dirname(image_zip)+'/train2014/'
else:
    PATH = os.path.abspath('.') + '/train2014/'
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 13s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 703s 0us/step

# %%
## Read the json file 
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

## Store captions and image names in vectors
all_captions = []
all_img_name_vector = []

for annot in annotations['annotations']:
    caption = '<start> ' + annot['caption'] + ' <end>'
    image_id = annot['image_id']
    full_coco_image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (image_id)

    all_img_name_vector.append(full_coco_image_path)
    all_captions.append(caption)

## Shuffle captions and image_names together
## Set a random state
train_captions, img_name_vector = shuffle(all_captions, all_img_name_vector, random_state=1)

## Select the first 100000 captions from the shuffled set
num_examples = 100000
train_captions = train_captions[:num_examples]
img_name_vector = img_name_vector[:num_examples]

# %%
len(train_captions), len(all_captions)
# Out:
# (100000, 414113)

# %% [markdown]
# ## Initialize InceptionV3 and load the pretrained Imagenet weights

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 6s 0us/step

# %% [markdown]
# ## Preprocess the image using Inception V3

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %% [markdown]
# ### Caching the features extracted from InceptionV3

# %%
## Get unique images
encode_train = sorted(set(img_name_vector))

## Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in image_dataset:
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features, (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        np.save(path_of_feature, bf.numpy())

# %% [markdown]
# ### Preprocess and tokenize the captions

# %%
## Find the maximum length of any caption in our dataset

def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
## Choose the top 5000 words from the vocabulary

top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
## Create the tokenized vectors

train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
## Pad each vector to the max_length of the captions
## If you do not provide a max_length value, pad_sequences calculates it automatically

cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
## Calculates the max_length, which is used to store the attention weights

max_length = calc_max_length(train_seqs)

# %% [markdown]
# ## Split the data into training and testing

# %%
## Create training and validation sets using an 80-20 split

img_name_train, img_name_val, cap_train, cap_val = train_test_split(img_name_vector, cap_vector, test_size=0.2, random_state=0)

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (80000, 80000, 20000, 20000)

# %% [markdown]
# ### Create a tf.data dataset for training

# %%
## Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = len(tokenizer.word_index) + 1
num_steps = len(img_name_train) // BATCH_SIZE

## Shape of the vector extracted from InceptionV3 is (64, 2048)
## These two variables represent that vector shape

features_shape = 2048
attention_features_shape = 64

# %%
## Load the numpy files

def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

## Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(map_func, [item1, item2], [tf.float32, tf.int32]),
                                num_parallel_calls=tf.data.experimental.AUTOTUNE)

## Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Model

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        ## features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

        ## hidden shape == (batch_size, hidden_size)
        ## hidden_with_time_axis shape == (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        ## score shape == (batch_size, 64, hidden_size)
        score = tf.nn.tanh(self.W1(features) + self.W2(hidden_with_time_axis))

        ## attention_weights shape == (batch_size, 64, 1)
        ## you get 1 at the last axis because you are applying score to self.V
        attention_weights = tf.nn.softmax(self.V(score), axis=1)

        ## context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    ## Since you have already extracted the features and dumped it using pickle
    ## This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        ## shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units, return_sequences=True, return_state=True, recurrent_initializer='glorot_uniform')
        self.fc1 = tf.keras.layers.Dense(self.units)
        self.fc2 = tf.keras.layers.Dense(vocab_size)
        self.attention = BahdanauAttention(self.units)

    def call(self, x, features, hidden):
        ## defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

        ## x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        ## x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        ## passing the concatenated vector to the GRU
        output, state = self.gru(x)

        ## shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

        ## x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

        ## output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# ### Checkpoints

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder, decoder=decoder, optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])

# %% [markdown]
# ### Training

# %%
## adding this in a separate cell because if you run the training cell
## many times, the loss_plot array will be reset

loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0

    ## initializing the hidden state for each batch
    ## because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * BATCH_SIZE, 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            ## passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

            ## using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
              epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    ## storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                         total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 2.1164
# Epoch 1 Batch 100 Loss 1.1352
# Epoch 1 Batch 200 Loss 1.0806
# Epoch 1 Batch 300 Loss 0.8917
# Epoch 1 Batch 400 Loss 0.8594
# Epoch 1 Batch 500 Loss 0.7478
# Epoch 1 Batch 600 Loss 0.7945
# Epoch 1 Batch 700 Loss 0.7470
# Epoch 1 Batch 800 Loss 0.8467
# Epoch 1 Batch 900 Loss 0.7550
# Epoch 1 Batch 1000 Loss 0.7626
# Epoch 1 Batch 1100 Loss 0.6773
# Epoch 1 Batch 1200 Loss 0.7599
# Epoch 1 Loss 0.849573
# Time taken for 1 epoch 871.4805543422699 sec
#
# Epoch 2 Batch 0 Loss 0.6547
# Epoch 2 Batch 100 Loss 0.7083
# Epoch 2 Batch 200 Loss 0.7437
# Epoch 2 Batch 300 Loss 0.6915
# Epoch 2 Batch 400 Loss 0.6871
# Epoch 2 Batch 500 Loss 0.6100
# Epoch 2 Batch 600 Loss 0.6952
# Epoch 2 Batch 700 Loss 0.6566
# Epoch 2 Batch 800 Loss 0.7439
# Epoch 2 Batch 900 Loss 0.6736
# Epoch 2 Batch 1000 Loss 0.6858
# Epoch 2 Batch 1100 Loss 0.6071
# Epoch 2 Batch 1200 Loss 0.6973
# Epoch 2 Loss 0.677324
# Time taken for 1 epoch 741.9032304286957 sec
#
# Epoch 3 Batch 0 Loss 0.5985
# Epoch 3 Batch 100 Loss 0.6549
# Epoch 3 Batch 200 Loss 0.6965
# Epoch 3 Batch 300 Loss 0.6378
# Epoch 3 Batch 400 Loss 0.6425
# Epoch 3 Batch 500 Loss 0.5659
# Epoch 3 Batch 600 Loss 0.6540
# Epoch 3 Batch 700 Loss 0.6112
# Epoch 3 Batch 800 Loss 0.6960
# Epoch 3 Batch 900 Loss 0.6279
# Epoch 3 Batch 1000 Loss 0.6552
# Epoch 3 Batch 1100 Loss 0.5740
# Epoch 3 Batch 1200 Loss 0.6548
# Epoch 3 Loss 0.633149
# Time taken for 1 epoch 732.6226201057434 sec
#
# Epoch 4 Batch 0 Loss 0.5736
# Epoch 4 Batch 100 Loss 0.6207
# Epoch 4 Batch 200 Loss 0.6611
# Epoch 4 Batch 300 Loss 0.6081
# Epoch 4 Batch 400 Loss 0.6136
# Epoch 4 Batch 500 Loss 0.5394
# Epoch 4 Batch 600 Loss 0.6217
# Epoch 4 Batch 700 Loss 0.5875
# Epoch 4 Batch 800 Loss 0.6609
# Epoch 4 Batch 900 Loss 0.5992
# Epoch 4 Batch 1000 Loss 0.6308
# Epoch 4 Batch 1100 Loss 0.5504
# Epoch 4 Batch 1200 Loss 0.6247
# Epoch 4 Loss 0.603706
# Time taken for 1 epoch 725.394558429718 sec
#
# Epoch 5 Batch 0 Loss 0.5593
# Epoch 5 Batch 100 Loss 0.6008
# Epoch 5 Batch 200 Loss 0.6339
# Epoch 5 Batch 300 Loss 0.5840
# Epoch 5 Batch 400 Loss 0.5899
# Epoch 5 Batch 500 Loss 0.5142
# Epoch 5 Batch 600 Loss 0.5921
# Epoch 5 Batch 700 Loss 0.5701
# Epoch 5 Batch 800 Loss 0.6299
# Epoch 5 Batch 900 Loss 0.5764
# Epoch 5 Batch 1000 Loss 0.6036
# Epoch 5 Batch 1100 Loss 0.5365
# Epoch 5 Batch 1200 Loss 0.5987
# Epoch 5 Loss 0.580222
# Time taken for 1 epoch 726.4333627223969 sec
#
# Epoch 6 Batch 0 Loss 0.5441
# Epoch 6 Batch 100 Loss 0.5762
# Epoch 6 Batch 200 Loss 0.6098
# Epoch 6 Batch 300 Loss 0.5648
# Epoch 6 Batch 400 Loss 0.5697
# Epoch 6 Batch 500 Loss 0.4944
# Epoch 6 Batch 600 Loss 0.5715
# Epoch 6 Batch 700 Loss 0.5462
# Epoch 6 Batch 800 Loss 0.6057
# Epoch 6 Batch 900 Loss 0.5574
# Epoch 6 Batch 1000 Loss 0.5817
# Epoch 6 Batch 1100 Loss 0.5176
# Epoch 6 Batch 1200 Loss 0.5737
# Epoch 6 Loss 0.559135
# Time taken for 1 epoch 733.0346713066101 sec
#
# Epoch 7 Batch 0 Loss 0.5247
# Epoch 7 Batch 100 Loss 0.5571
# Epoch 7 Batch 200 Loss 0.5935
# Epoch 7 Batch 300 Loss 0.5482
# Epoch 7 Batch 400 Loss 0.5525
# Epoch 7 Batch 500 Loss 0.4818
# Epoch 7 Batch 600 Loss 0.5506
# Epoch 7 Batch 700 Loss 0.5279
# Epoch 7 Batch 800 Loss 0.5892
# Epoch 7 Batch 900 Loss 0.5407
# Epoch 7 Batch 1000 Loss 0.5546
# Epoch 7 Batch 1100 Loss 0.5045
# Epoch 7 Batch 1200 Loss 0.5500
# Epoch 7 Loss 0.540523
# Time taken for 1 epoch 729.4963958263397 sec
#
# Epoch 8 Batch 0 Loss 0.5084
# Epoch 8 Batch 100 Loss 0.5457
# Epoch 8 Batch 200 Loss 0.5767
# Epoch 8 Batch 300 Loss 0.5306
# Epoch 8 Batch 400 Loss 0.5425
# Epoch 8 Batch 500 Loss 0.4698
# Epoch 8 Batch 600 Loss 0.5266
# Epoch 8 Batch 700 Loss 0.5183
# Epoch 8 Batch 800 Loss 0.5690
# Epoch 8 Batch 900 Loss 0.5206
# Epoch 8 Batch 1000 Loss 0.5376
# Epoch 8 Batch 1100 Loss 0.4923
# Epoch 8 Batch 1200 Loss 0.5336
# Epoch 8 Loss 0.524062
# Time taken for 1 epoch 723.126181602478 sec
#
# Epoch 9 Batch 0 Loss 0.4990
# Epoch 9 Batch 100 Loss 0.5320
# Epoch 9 Batch 200 Loss 0.5561
# Epoch 9 Batch 300 Loss 0.5151
# Epoch 9 Batch 400 Loss 0.5242
# Epoch 9 Batch 500 Loss 0.4608
# Epoch 9 Batch 600 Loss 0.5102
# Epoch 9 Batch 700 Loss 0.5086
# Epoch 9 Batch 800 Loss 0.5525
# Epoch 9 Batch 900 Loss 0.5061
# Epoch 9 Batch 1000 Loss 0.5240
# Epoch 9 Batch 1100 Loss 0.4776
# Epoch 9 Batch 1200 Loss 0.5190
# Epoch 9 Loss 0.510637
# Time taken for 1 epoch 724.6867139339447 sec
#
# Epoch 10 Batch 0 Loss 0.4835
# Epoch 10 Batch 100 Loss 0.5197
# Epoch 10 Batch 200 Loss 0.5433
# Epoch 10 Batch 300 Loss 0.4951
# Epoch 10 Batch 400 Loss 0.5093
# Epoch 10 Batch 500 Loss 0.4435
# Epoch 10 Batch 600 Loss 0.4943
# Epoch 10 Batch 700 Loss 0.4967
# Epoch 10 Batch 800 Loss 0.5417
# Epoch 10 Batch 900 Loss 0.4925
# Epoch 10 Batch 1000 Loss 0.5234
# Epoch 10 Batch 1100 Loss 0.4615
# Epoch 10 Batch 1200 Loss 0.5158
# Epoch 10 Loss 0.497133
# Time taken for 1 epoch 724.1253271102905 sec
#
# Epoch 11 Batch 0 Loss 0.4762
# Epoch 11 Batch 100 Loss 0.4982
# Epoch 11 Batch 200 Loss 0.5344
# Epoch 11 Batch 300 Loss 0.4925
# Epoch 11 Batch 400 Loss 0.5051
# Epoch 11 Batch 500 Loss 0.4337
# Epoch 11 Batch 600 Loss 0.4914
# Epoch 11 Batch 700 Loss 0.4901
# Epoch 11 Batch 800 Loss 0.5276
# Epoch 11 Batch 900 Loss 0.4785
# Epoch 11 Batch 1000 Loss 0.4963
# Epoch 11 Batch 1100 Loss 0.4513
# Epoch 11 Batch 1200 Loss 0.5052
# Epoch 11 Loss 0.486145
# Time taken for 1 epoch 726.3449652194977 sec
#
# Epoch 12 Batch 0 Loss 0.4628
# Epoch 12 Batch 100 Loss 0.4883
# Epoch 12 Batch 200 Loss 0.5254
# Epoch 12 Batch 300 Loss 0.4766
# Epoch 12 Batch 400 Loss 0.4999
# Epoch 12 Batch 500 Loss 0.4261
# Epoch 12 Batch 600 Loss 0.4775
# Epoch 12 Batch 700 Loss 0.4867
# Epoch 12 Batch 800 Loss 0.5175
# Epoch 12 Batch 900 Loss 0.4739
# Epoch 12 Batch 1000 Loss 0.4907
# Epoch 12 Batch 1100 Loss 0.4380
# Epoch 12 Batch 1200 Loss 0.4824
# Epoch 12 Loss 0.476909
# Time taken for 1 epoch 731.2584095001221 sec
#
# Epoch 13 Batch 0 Loss 0.4584
# Epoch 13 Batch 100 Loss 0.4732
# Epoch 13 Batch 200 Loss 0.5171
# Epoch 13 Batch 300 Loss 0.4698
# Epoch 13 Batch 400 Loss 0.4936
# Epoch 13 Batch 500 Loss 0.4233
# Epoch 13 Batch 600 Loss 0.4663
# Epoch 13 Batch 700 Loss 0.4769
# Epoch 13 Batch 800 Loss 0.5184
# Epoch 13 Batch 900 Loss 0.4674
# Epoch 13 Batch 1000 Loss 0.4767
# Epoch 13 Batch 1100 Loss 0.4337
# Epoch 13 Batch 1200 Loss 0.4619
# Epoch 13 Loss 0.468563
# Time taken for 1 epoch 726.7486550807953 sec
#
# Epoch 14 Batch 0 Loss 0.4476
# Epoch 14 Batch 100 Loss 0.4588
# Epoch 14 Batch 200 Loss 0.5123
# Epoch 14 Batch 300 Loss 0.4557
# Epoch 14 Batch 400 Loss 0.4822
# Epoch 14 Batch 500 Loss 0.4020
# Epoch 14 Batch 600 Loss 0.4563
# Epoch 14 Batch 700 Loss 0.4609
# Epoch 14 Batch 800 Loss 0.4995
# Epoch 14 Batch 900 Loss 0.4513
# Epoch 14 Batch 1000 Loss 0.4662
# Epoch 14 Batch 1100 Loss 0.4296
# Epoch 14 Batch 1200 Loss 0.4580
# Epoch 14 Loss 0.457801
# Time taken for 1 epoch 728.3819246292114 sec
#
# Epoch 15 Batch 0 Loss 0.4403
# Epoch 15 Batch 100 Loss 0.4566
# Epoch 15 Batch 200 Loss 0.5058
# Epoch 15 Batch 300 Loss 0.4436
# Epoch 15 Batch 400 Loss 0.4660
# Epoch 15 Batch 500 Loss 0.3902
# Epoch 15 Batch 600 Loss 0.4573
# Epoch 15 Batch 700 Loss 0.4504
# Epoch 15 Batch 800 Loss 0.4825
# Epoch 15 Batch 900 Loss 0.4412
# Epoch 15 Batch 1000 Loss 0.4511
# Epoch 15 Batch 1100 Loss 0.4302
# Epoch 15 Batch 1200 Loss 0.4605
# Epoch 15 Loss 0.448321
# Time taken for 1 epoch 738.6495501995087 sec
#
# Epoch 16 Batch 0 Loss 0.4309
# Epoch 16 Batch 100 Loss 0.4405
# Epoch 16 Batch 200 Loss 0.5122
# Epoch 16 Batch 300 Loss 0.4326
# Epoch 16 Batch 400 Loss 0.4647
# Epoch 16 Batch 500 Loss 0.3852
# Epoch 16 Batch 600 Loss 0.4513
# Epoch 16 Batch 700 Loss 0.4362
# Epoch 16 Batch 800 Loss 0.4708
# Epoch 16 Batch 900 Loss 0.4311
# Epoch 16 Batch 1000 Loss 0.4418
# Epoch 16 Batch 1100 Loss 0.4258
# Epoch 16 Batch 1200 Loss 0.4372
# Epoch 16 Loss 0.440668
# Time taken for 1 epoch 757.1989243030548 sec
#
# Epoch 17 Batch 0 Loss 0.4284
# Epoch 17 Batch 100 Loss 0.4421
# Epoch 17 Batch 200 Loss 0.5001
# Epoch 17 Batch 300 Loss 0.4289
# Epoch 17 Batch 400 Loss 0.4491
# Epoch 17 Batch 500 Loss 0.3727
# Epoch 17 Batch 600 Loss 0.4360
# Epoch 17 Batch 700 Loss 0.4313
# Epoch 17 Batch 800 Loss 0.4591
# Epoch 17 Batch 900 Loss 0.4252
# Epoch 17 Batch 1000 Loss 0.4356
# Epoch 17 Batch 1100 Loss 0.4291
# Epoch 17 Batch 1200 Loss 0.4200
# Epoch 17 Loss 0.433083
# Time taken for 1 epoch 761.9849739074707 sec
#
# Epoch 18 Batch 0 Loss 0.4288
# Epoch 18 Batch 100 Loss 0.4437
# Epoch 18 Batch 200 Loss 0.4844
# Epoch 18 Batch 300 Loss 0.4304
# Epoch 18 Batch 400 Loss 0.4416
# Epoch 18 Batch 500 Loss 0.3701
# Epoch 18 Batch 600 Loss 0.4305
# Epoch 18 Batch 700 Loss 0.4292
# Epoch 18 Batch 800 Loss 0.4570
# Epoch 18 Batch 900 Loss 0.4296
# Epoch 18 Batch 1000 Loss 0.4268
# Epoch 18 Batch 1100 Loss 0.4242
# Epoch 18 Batch 1200 Loss 0.4236
# Epoch 18 Loss 0.426287
# Time taken for 1 epoch 756.8600215911865 sec
#
# Epoch 19 Batch 0 Loss 0.4263
# Epoch 19 Batch 100 Loss 0.4350
# Epoch 19 Batch 200 Loss 0.4770
# Epoch 19 Batch 300 Loss 0.4358
# Epoch 19 Batch 400 Loss 0.4300
# Epoch 19 Batch 500 Loss 0.3576
# Epoch 19 Batch 600 Loss 0.4249
# Epoch 19 Batch 700 Loss 0.4163
# Epoch 19 Batch 800 Loss 0.4555
# Epoch 19 Batch 900 Loss 0.4252
# Epoch 19 Batch 1000 Loss 0.4207
# Epoch 19 Batch 1100 Loss 0.4116
# Epoch 19 Batch 1200 Loss 0.4275
# Epoch 19 Loss 0.420451
# Time taken for 1 epoch 757.784720659256 sec
#
# Epoch 20 Batch 0 Loss 0.4273
# Epoch 20 Batch 100 Loss 0.4251
# Epoch 20 Batch 200 Loss 0.4745
# Epoch 20 Batch 300 Loss 0.4256
# Epoch 20 Batch 400 Loss 0.4295
# Epoch 20 Batch 500 Loss 0.3416
# Epoch 20 Batch 600 Loss 0.4103
# Epoch 20 Batch 700 Loss 0.4048
# Epoch 20 Batch 800 Loss 0.4433
# Epoch 20 Batch 900 Loss 0.4117
# Epoch 20 Batch 1000 Loss 0.4177
# Epoch 20 Batch 1100 Loss 0.4005
# Epoch 20 Batch 1200 Loss 0.4154
# Epoch 20 Loss 0.411530
# Time taken for 1 epoch 753.5970451831818 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Caption!

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (8, 8))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
## captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print ('Real Caption:', real_caption)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
## opening the image
Image.open(img_name_val[rid])
# Out:
# Real Caption: <start> two zebras sitting in a grassy field next to trees <end>
# Prediction Caption: a zebra is standing in a zoo <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x450 at 0x7F94F74145F8>

# %%
## captions on the validation set
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
## opening the image
Image.open(image_path)
# Out:
# Downloading data from https://tensorflow.org/images/surf.jpg
# 65536/64400 [==============================] - 0s 2us/step
# Prediction Caption: a man riding a wave on a wave <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F94F719CBA8>

# %%
## captions on the validation set
image_url = 'https://brewminate.com/wp-content/uploads/2016/05/Decisions01.png'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
## opening the image
Image.open(image_path)
# Out:
# Downloading data from https://brewminate.com/wp-content/uploads/2016/05/Decisions01.png
# 434176/430789 [==============================] - 1s 3us/step
# Prediction Caption: a vase filled with trees trees <end>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=590x288 at 0x7F94F6E47518>

# %%
## captions on the validation set
image_url = 'https://www.uniconexed.org/wp-content/uploads/2016/05/webhomes-complex-to-simple-1024x576-770x433.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
## opening the image
Image.open(image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F94F668AF60>
